# %% [markdown]
# # Full Pipeline Notebook (Colab)\nThis notebook JSON contains a complete cell-by-cell outline for the end-to-end paper pipeline.\n\n## JSON structure\n- kernelspec: python3\n- language_info: Python 3.10\n- cells: 14 cells, exactly as listed below\n

# %% [markdown]
# ## Cell 1: pip installs\nInstall requirements and verify environment.\n

# %% [markdown]
# ## Cell 2: Clone repo, set paths\nClone repository in Colab and set working paths.\n

# %% [markdown]
# ## Cell 3: Run generate_dataset.py, display summary stats\nGenerate data and print rows, anomaly rate, class counts.\n

# %% [markdown]
# ## Cell 4: Fault class distribution plot (Figure 3a)\n

# %% [markdown]
# ## Cell 5: Channel statistics (Figure 3b)\n

# %% [markdown]
# ## Cell 6: RP images per fault class (Figure 4)\n

# %% [markdown]
# ## Cell 7: Train CNN autoencoder, convergence (Figure 6a)\n

# %% [markdown]
# ## Cell 8: Train LSTM autoencoder, convergence (Figure 6b)\n

# %% [markdown]
# ## Cell 9: Train Standard AE and Isolation Forest\n

# %% [markdown]
# ## Cell 10: Overall performance table (Table 1 / Figure 8)\n

# %% [markdown]
# ## Cell 11: Per-fault-type F1 table (Table 2 / Figure 9)\n

# %% [markdown]
# ## Cell 12: Noise generalization comparison (Figure 10)\n

# %% [markdown]
# ## Cell 13: Reconstruction error distributions (Figure 11)\n

# %% [markdown]
# ## Final cell: Summary and match-to-paper confirmation\nPrint all key values and confirm match to reported results.\n
